# %%
#Algoritmo de Treinamento do Perceptron

#Funcao de ativacao
def funcaoLimiar(v):
  if v>=0: return 1
  else: return 0

def propagacao(tupla,pesos):
  v = pesos[0] + pesos[1] * tupla[0] + pesos[2] * tupla[1]
  return v

# %%
def algoritmoTreinamento(dados):
  epoca = 0
  eta = 1
  pesos = [0,0,0]
  print("Pesos iniciais: ", pesos)

  erroGeral = 1
  while erroGeral!=0 and epoca<=100:
    erroGeral = 0
    epoca = epoca + 1
    print("\nEpoca: ", epoca)
    for tupla in dados:
      print("Processando: ", tupla)
      v = propagacao(tupla,pesos)
      y = funcaoLimiar(v)
      erro = tupla[2] - y
      print('Erro = ', erro)
      if erro!=0:
        delta = eta * erro
        pesos[0] = pesos[0] + delta
        delta = eta * erro * tupla[0]
        pesos[1] = pesos[1] + delta
        delta = eta * erro * tupla[1]
        pesos[2] = pesos[2] + delta
      print("Pesos atuais: ", pesos)
      erroGeral = erroGeral + abs(erro)

  return pesos

# %%
#Tabela OR
x1 = [1.0000, 0.4643, 0.5000, 0.1786, 0.3929, 0.6429, 0.8571, 0.6964, 0.1607, 0.9821, 0.3036, 0.4643, 0.7500, 0.3214, 0.9643]

x2 = [0.6875, 0.6250, 0.1000, 0.2500, 0.3375, 0.5625, 0.8125, 0.7500, 0.0875, 0.9125, 0.1125, 0.2500, 0.9375, 0.3750, 0.3125]
d  = [1, 0, 1, 0, 0, 1, 1, 1, 0, 1, 0, 0, 1, 0, 1]

dados = []
print('x1  x2  d')
for i in range(0,len(x1)):
  print(x1[i], ' ', x2[i], ' ', d[i])
  dados.append([x1[i],x2[i],d[i]])
#print(dados)
# Out:
# x1  x2  d
# 1.0   0.6875   1
# 0.4643   0.625   0
# 0.5   0.1   1
# 0.1786   0.25   0
# 0.3929   0.3375   0
# 0.6429   0.5625   1
# 0.8571   0.8125   1
# 0.6964   0.75   1
# 0.1607   0.0875   0
# 0.9821   0.9125   1
# 0.3036   0.1125   0
# 0.4643   0.25   0
# 0.75   0.9375   1
# 0.3214   0.375   0
# 0.9643   0.3125   1

# %%
#Treinamento
w = algoritmoTreinamento(dados)
# Out:
# Pesos iniciais:  [0, 0, 0]
#
# Epoca:  1
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [0, 0, 0]
# Processando:  [0.4643, 0.625, 0]
# Erro =  -1
# Pesos atuais:  [-1, -0.4643, -0.625]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [0, 0.03570000000000001, -0.525]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [0, 0.03570000000000001, -0.525]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  0
# Pesos atuais:  [0, 0.03570000000000001, -0.525]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  1
# Pesos atuais:  [1, 0.6786000000000001, 0.03749999999999998]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [1, 0.6786000000000001, 0.03749999999999998]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [1, 0.6786000000000001, 0.03749999999999998]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  -1
# Pesos atuais:  [0, 0.5179, -0.05000000000000002]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [0, 0.5179, -0.05000000000000002]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  -1
# Pesos atuais:  [-1, 0.21430000000000005, -0.16250000000000003]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 0.21430000000000005, -0.16250000000000003]
# Processando:  [0.75, 0.9375, 1]
# Erro =  1
# Pesos atuais:  [0, 0.9643, 0.7749999999999999]
# Processando:  [0.3214, 0.375, 0]
# Erro =  -1
# Pesos atuais:  [-1, 0.6429, 0.3999999999999999]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  1
# Pesos atuais:  [0, 1.6072000000000002, 0.7124999999999999]
#
# Epoca:  2
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [0, 1.6072000000000002, 0.7124999999999999]
# Processando:  [0.4643, 0.625, 0]
# Erro =  -1
# Pesos atuais:  [-1, 1.1429000000000002, 0.08749999999999991]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [0, 1.6429000000000002, 0.18749999999999992]
# Processando:  [0.1786, 0.25, 0]
# Erro =  -1
# Pesos atuais:  [-1, 1.4643000000000002, -0.06250000000000008]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  0
# Pesos atuais:  [-1, 1.4643000000000002, -0.06250000000000008]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  1
# Pesos atuais:  [0, 2.1072, 0.4999999999999999]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [0, 2.1072, 0.4999999999999999]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [0, 2.1072, 0.4999999999999999]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  -1
# Pesos atuais:  [-1, 1.9465000000000001, 0.41249999999999987]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-1, 1.9465000000000001, 0.41249999999999987]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-1, 1.9465000000000001, 0.41249999999999987]
# Processando:  [0.4643, 0.25, 0]
# Erro =  -1
# Pesos atuais:  [-2, 1.4822000000000002, 0.16249999999999987]
# Processando:  [0.75, 0.9375, 1]
# Erro =  1
# Pesos atuais:  [-1, 2.2322, 1.0999999999999999]
# Processando:  [0.3214, 0.375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 1.9108, 0.7249999999999999]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 1.9108, 0.7249999999999999]
#
# Epoca:  3
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 1.9108, 0.7249999999999999]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 1.9108, 0.7249999999999999]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 2.4108, 0.8249999999999998]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 2.4108, 0.8249999999999998]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 2.0179, 0.4874999999999998]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  1
# Pesos atuais:  [-1, 2.6608, 1.0499999999999998]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-1, 2.6608, 1.0499999999999998]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-1, 2.6608, 1.0499999999999998]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-1, 2.6608, 1.0499999999999998]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-1, 2.6608, 1.0499999999999998]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-1, 2.6608, 1.0499999999999998]
# Processando:  [0.4643, 0.25, 0]
# Erro =  -1
# Pesos atuais:  [-2, 2.1965, 0.7999999999999998]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.1965, 0.7999999999999998]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.1965, 0.7999999999999998]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.1965, 0.7999999999999998]
#
# Epoca:  4
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.1965, 0.7999999999999998]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.1965, 0.7999999999999998]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 2.6965, 0.8999999999999998]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 2.6965, 0.8999999999999998]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 2.3036, 0.5624999999999998]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  1
# Pesos atuais:  [-1, 2.9465, 1.1249999999999998]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-1, 2.9465, 1.1249999999999998]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-1, 2.9465, 1.1249999999999998]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-1, 2.9465, 1.1249999999999998]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-1, 2.9465, 1.1249999999999998]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  -1
# Pesos atuais:  [-2, 2.6429, 1.0124999999999997]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.6429, 1.0124999999999997]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.6429, 1.0124999999999997]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.6429, 1.0124999999999997]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.6429, 1.0124999999999997]
#
# Epoca:  5
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.6429, 1.0124999999999997]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.6429, 1.0124999999999997]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 3.1429, 1.1124999999999998]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 3.1429, 1.1124999999999998]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
#
# Epoca:  6
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.75, 0.7749999999999998]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 3.25, 0.8749999999999998]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 3.25, 0.8749999999999998]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
#
# Epoca:  7
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.8571, 0.5374999999999998]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 3.3571, 0.6374999999999997]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 3.3571, 0.6374999999999997]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
#
# Epoca:  8
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 2.9642, 0.2999999999999997]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 3.4642, 0.3999999999999997]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 3.4642, 0.3999999999999997]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
#
# Epoca:  9
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.0713, 0.06249999999999967]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 3.5713, 0.16249999999999967]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 3.5713, 0.16249999999999967]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 3.1784, -0.17500000000000035]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  1
# Pesos atuais:  [-1, 3.8213, 0.3874999999999996]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-1, 3.8213, 0.3874999999999996]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-1, 3.8213, 0.3874999999999996]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-1, 3.8213, 0.3874999999999996]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-1, 3.8213, 0.3874999999999996]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  -1
# Pesos atuais:  [-2, 3.5177, 0.27499999999999963]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.5177, 0.27499999999999963]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.5177, 0.27499999999999963]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.5177, 0.27499999999999963]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.5177, 0.27499999999999963]
#
# Epoca:  10
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.5177, 0.27499999999999963]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.5177, 0.27499999999999963]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 4.0177, 0.37499999999999967]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 4.0177, 0.37499999999999967]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
#
# Epoca:  11
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.6247999999999996, 0.037499999999999645]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 4.1248, 0.13749999999999965]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 4.1248, 0.13749999999999965]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
#
# Epoca:  12
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.7318999999999996, -0.20000000000000037]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 4.2318999999999996, -0.10000000000000037]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 4.2318999999999996, -0.10000000000000037]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
#
# Epoca:  13
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.8389999999999995, -0.4375000000000004]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 4.3389999999999995, -0.33750000000000036]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 4.3389999999999995, -0.33750000000000036]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
#
# Epoca:  14
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 3.9460999999999995, -0.6750000000000004]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 4.4460999999999995, -0.5750000000000004]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 4.4460999999999995, -0.5750000000000004]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
#
# Epoca:  15
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.0531999999999995, -0.9125000000000004]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 4.5531999999999995, -0.8125000000000004]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 4.5531999999999995, -0.8125000000000004]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
#
# Epoca:  16
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.160299999999999, -1.1500000000000004]
# Processando:  [0.5, 0.1, 1]
# Erro =  1
# Pesos atuais:  [-1, 4.660299999999999, -1.0500000000000003]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-1, 4.660299999999999, -1.0500000000000003]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  -1
# Pesos atuais:  [-2, 4.267399999999999, -1.3875000000000002]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  1
# Pesos atuais:  [-1, 4.910299999999999, -0.8250000000000002]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-1, 4.910299999999999, -0.8250000000000002]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-1, 4.910299999999999, -0.8250000000000002]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-1, 4.910299999999999, -0.8250000000000002]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-1, 4.910299999999999, -0.8250000000000002]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  -1
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
#
# Epoca:  17
# Processando:  [1.0, 0.6875, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.4643, 0.625, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.5, 0.1, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.1786, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.3929, 0.3375, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.6429, 0.5625, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.8571, 0.8125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.6964, 0.75, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.1607, 0.0875, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.9821, 0.9125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.3036, 0.1125, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.4643, 0.25, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.75, 0.9375, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.3214, 0.375, 0]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]
# Processando:  [0.9643, 0.3125, 1]
# Erro =  0
# Pesos atuais:  [-2, 4.606699999999999, -0.9375000000000002]

# %%
#Generalizacao

entrada1 = float(input('Informe o valor de x1: '))
entrada2 = float(input('Informe o valor de x2: '))
tuplaEntrada = [entrada1,entrada2]

v = propagacao(tuplaEntrada,w)
y = funcaoLimiar(v)
print('Saida da rede: ', y)
# Out:
# Saida da rede:  1
